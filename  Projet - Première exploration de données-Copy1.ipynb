# %%
import numpy as np
import pandas as pd
data=pd.read_csv('data-essai2.csv', sep=';')

# %%
#infos sur la table et ses colonnes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#format du dataset 
data.shape
#541909 lignes et 8 colonnes
# Out:
# (541909, 8)

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#affichage des 5 premières lignes du dataset
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
print(data.InvoiceDate.min())
# Out:
# 2010-12-01 08:26:00

# %%
print(data.InvoiceDate.max())
# Out:
# 2011-12-09 12:50:00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
####################################################

# %%
''' Etude des Valeurs manquantes '''
# Out:
# ' Etude des Valeurs manquantes '

# %%
####################################################

# %%
#détéction des colonnes avec au moins une valeur manquante 
data.isna().any(axis=0)
#les colonnes description et customerID contienent des valeurs manquantes
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
#Affichage des lignes qui ont au moins une valeur manquante 
data[data.isna().any(axis=1)]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#calcul du nombre de valeurs manquantes pour chaque colonne
data.isnull().sum(axis=0)
# remarque : lorsque la colonne description contient une valeur manquante, la colonne customerID également
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#affichage des 30 premières entrées contenant au moins un Na dans les colonnes Description et CustomerID
data[data[['Description','CustomerID' ]].isna().any(axis=1)].head(30)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 622     536414     22139                                  NaN        56
# 1443    536544     21773      DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774      DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786                   POLKADOT RAIN HAT          4
# 1446    536544     21787                RAIN PONCHO RETROSPOT         2
# 1447    536544     21790                   VINTAGE SNAP CARDS         9
# 1448    536544     21791   VINTAGE HEADS AND TAILS CARD GAME          2
# 1449    536544     21801  CHRISTMAS TREE DECORATION WITH BELL        10
# 1450    536544     21802      CHRISTMAS TREE HEART DECORATION         9
# 1451    536544     21803       CHRISTMAS TREE STAR DECORATION        11
# 1452    536544     21809     CHRISTMAS HANGING TREE WITH BELL         1
# 1453    536544     21810     CHRISTMAS HANGING STAR WITH BELL         3
# ...

# %%
#affichage des 30 premières entrées contenant un Na dans la colonne Description 
data[data[['Description' ]].isna().any(axis=1)].head(30)
# remarque : lorsque la colonne description contient une valeur manquante, on a l'impression
# que la colonne customerID contient également une valeur manquante 
#hypothèse vérifiée lors du code suivant
# Out:
#      InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56  12/01/2010 11:52        0.0
# 1970    536545     21134         NaN         1  12/01/2010 14:32        0.0
# 1971    536546     22145         NaN         1  12/01/2010 14:33        0.0
# 1972    536547     37509         NaN         1  12/01/2010 14:33        0.0
# 1987    536549    85226A         NaN         1  12/01/2010 14:34        0.0
# 1988    536550     85044         NaN         1  12/01/2010 14:34        0.0
# 2024    536552     20950         NaN         1  12/01/2010 14:34        0.0
# 2025    536553     37461         NaN         3  12/01/2010 14:35        0.0
# 2026    536554     84670         NaN        23  12/01/2010 14:35        0.0
# 2406    536589     21777         NaN       -10  12/01/2010 16:50        0.0
# 4347    536764    84952C         NaN       -38  12/02/2010 14:42        0.0
# ...

# %%
#code permettant de connaître les différentes valeurs de CustomerID lorsque la colonne Description
#contient une valeur manquante
data[data[['Description']].isna().any(axis=1)].CustomerID.unique()
# uniquement nan --> lorsque la colonne description contient une valeur manquante, la colonne customerID également
# Out:
# array([nan])

# %%
#code permettant de connaître les différentes valeurs de prix lorsque la colonne Description = NaN
data[data[['Description']].isna().any(axis=1)].UnitPrice.unique()
# prix = 0 pour toutes les fois où nous avons une description = Nan
# Out:
# array([0.])

# %%
data[data[['Description']].isna().any(axis=1)].InvoiceNo.unique()
# Out:
# array(['536414', '536545', '536546', ..., '581209', '581234', '581408'],
#       dtype=object)

# %%
data[data[['Description' ]].isna().any(axis=1)].sort_values(by='Quantity', ascending=False)
# remarque : lorsque Description = NaN, et quantity < 0, InvoiceNo ne contient pas le caractère 'C' avant le numéro
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 74614     542504     37413         NaN      5568   1/28/2011 12:03        0.0
# 74615     542505    79063D         NaN      2560   1/28/2011 12:04        0.0
# 82795     543258    84611B         NaN      1287  02/04/2011 16:06        0.0
# 136537    547966       DOT         NaN      1000   3/28/2011 15:49        0.0
# 52262     540699      POST         NaN      1000  01/11/2011 09:32        0.0
# ...          ...       ...         ...       ...               ...        ...
# 44863     540241     35957         NaN      -939  01/05/2011 15:17        0.0
# 156350    550133    85099F         NaN     -1092   4/14/2011 13:49        0.0
# 270886    560600     18007         NaN     -2834   7/19/2011 17:04        0.0
# 323458    565304     16259         NaN     -3167  09/02/2011 12:18        0.0
# 341601    566768     16045         NaN     -3667   9/14/2011 17:53        0.0
#
# ...

# %%
# calcul du nombre de fois où l'on a des quantités négatives 
data[data['Quantity']<0].Quantity.count()
#10624 valeurs négatives pour la quantité dans notre jeu de données
# Out:
# 10624

# %%
# calcul du nombre de fois où l'on a des quantités positives
data[data['Quantity']>0].Quantity.count()
#531285 valeurs positives
# Out:
# 531285

# %%
# As-t-on des quantités nulles ? 
data[data['Quantity']==0].Quantity.count()
#--> non
# Out:
# 0

# %%
#code permettant de connaître les différents pays pour lesquels nous avons une donnée manquante dans la col Description
data[data[['Description']].isna().any(axis=1)].Country.unique()
#donnée manquantes uniquement lorsque le pays est 'United Kingdom'
# Out:
# array(['United Kingdom'], dtype=object)

# %%
#code permettant de connaître les différents pays pour lesquels nous avons une donnée manquante dans la col CustomerID
data[data[['CustomerID']].isna().any(axis=1)].Country.unique()
# Out:
# array(['United Kingdom', 'EIRE', 'Bahrain', 'Israel', 'Hong Kong',
#        'Unspecified', 'France', 'Switzerland', 'Portugal'], dtype=object)

# %%
#code pour connaître les différents pays pour lesquels nous avons une donnée manquante dans la col CustomerID
#ainsi que le nombre de fois 
data[data[['CustomerID']].isna().any(axis=1)].Country.value_counts()
# Out:
# United Kingdom    133600
# EIRE                 711
# Hong Kong            288
# Unspecified          202
# Switzerland          125
# France                66
# Israel                47
# Portugal              39
# Bahrain                2
# Name: Country, dtype: int64

# %%
####################################################

# %%
''' Etude de la colonne Country et CustomerID'''

# %%
####################################################

# %%
#affichage des différents pays présents dans le dataset
data['Country'].unique()
#38 pays différents
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
#nombre de pays différents
np.count_nonzero(data['Country'].unique())
# Out:
# 38

# %%
#nombre d'articles différents vendues par pays 
#(ou nombre de lignes dans le tableau)
data['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
#part d'articles différents vendus par pays
data['Country'].value_counts(normalize = True)
#91,4% des articles vendus à UK
#le reste des pays comptabilisent moins de 2% des commandes
#données non équilibrées
# Out:
# United Kingdom          0.914320
# Germany                 0.017521
# France                  0.015790
# EIRE                    0.015124
# Spain                   0.004674
# Netherlands             0.004375
# Belgium                 0.003818
# Switzerland             0.003694
# Portugal                0.002803
# Australia               0.002323
# Norway                  0.002004
# Italy                   0.001482
# Channel Islands         0.001399
# Finland                 0.001283
# Cyprus                  0.001148
# Sweden                  0.000853
# Unspecified             0.000823
# Austria                 0.000740
# Denmark                 0.000718
# Japan                   0.000661
# Poland                  0.000629
# Israel                  0.000548
# USA                     0.000537
# Hong Kong               0.000531
# Singapore               0.000423
# Iceland                 0.000336
# Canada                  0.000279
# Greece                  0.000269
# ...

# %%
#nombre de clients différents
np.count_nonzero(data['CustomerID'].unique())
# Out:
# 4373

# %%
#nombre de lignes par client (ou nombre de produits différents acheté par client)
data['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 13391.0       1
# 16579.0       1
# 13366.0       1
# 17763.0       1
# 17846.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
data['CustomerID'].value_counts(normalize = True)
#les données ont l'aire plutôt équilibrées
#il y'a de gros clients et des petits clients, ce qui est normal
# Out:
# 17841.0    0.019622
# 14911.0    0.014510
# 14096.0    0.012605
# 12748.0    0.011410
# 14606.0    0.006838
#              ...
# 13391.0    0.000002
# 16579.0    0.000002
# 13366.0    0.000002
# 17763.0    0.000002
# 17846.0    0.000002
# Name: CustomerID, Length: 4372, dtype: float64

# %%
#exemple : zoom sur les commandes du client 15311
data[data['CustomerID']==15311]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 106       536381     22139     RETROSPOT TEA SET CERAMIC 11 PC         23
# 107       536381     84854                  GIRLY PINK TOOL SET         5
# 108       536381     22411    JUMBO SHOPPER VINTAGE RED PAISLEY        10
# 109       536381     82567            AIRLINE LOUNGE,METAL SIGN         2
# 110       536381     21672   WHITE SPOT RED CERAMIC DRAWER KNOB         6
# ...          ...       ...                                  ...       ...
# 541746    581571     23167       SMALL CERAMIC TOP STORAGE JAR         96
# 541747    581571     21314        SMALL GLASS HEART TRINKET POT        48
# 541748    581571     21137             BLACK RECORD COVER FRAME        24
# 541749    581571     44234             ASSORTED CIRCULAR MOBILE         1
# 541750    581571     84347  ROTATING SILVER ANGELS T-LIGHT HLDR        24
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#est-ce qu'on a bien un seul identifiant client renseigné pour un numéro de facture donné ? 
#je calcule le nombre d'identifiants client par numéro de facture dans un nouveau dataframe

#fonction nombre de modalités
n_modalite=lambda colonne : len(np.unique(colonne))

#fonction à appliquer au groupby
function_to_apply = {'CustomerID': n_modalite}


#j'enlève les données manquantes de customerID pour notre essai
data_no_na=data.dropna(axis=0, how='all', subset=['CustomerID'])

#création d'un dataframe contenant le nombre d'identifiant client par numéro de facture
nombre_commande_client=data_no_na.groupby('InvoiceNo').agg(function_to_apply)

#ordre décroissant du nombre d'identifiants clients
nombre_commande_client.sort_values(by='CustomerID', ascending=False)
#un numéro de facture correspond bien à un seul client
# Out:
#            CustomerID
# InvoiceNo
# 536365            1.0
# 572990            1.0
# 573002            1.0
# 573001            1.0
# 573000            1.0
# ...               ...
# 555108            1.0
# 555107            1.0
# 555106            1.0
# 555104            1.0
# C581569           1.0
#
# [22190 rows x 1 columns]

# %%
####################################################

# %%
''' Etude de la variable Quantity'''
''' le but étant de comprendre pourquoi nous avons parfois des quantités négatives ?
quel lien avec la colonne CustomerID ?
que pouvons-nous remarquer sur la quantité et InvoiceNo lorsque CustomerID = NaN ?'''

# %%
#ordre décroissant de la quantité
data.sort_values(by='Quantity', ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# ...          ...       ...                                  ...       ...
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225530    556691     23005         printing smudges/thrown away     -9600
# 225529    556690     23005         printing smudges/thrown away     -9600
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.sort_values(by='Quantity', ascending=False).head(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 220843    556231    85123A                                    ?      4000
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 263885    560040     23343                  came coded as 20713      3100
# ...

# %%
data.sort_values(by='Quantity', ascending=True).head(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225528    556687     23003         Printing smudges/thrown away     -9058
# 115818    546152    72140F                           throw away     -5368
# 431381    573596    79323W               Unsaleable, destroyed.     -4830
# 341601    566768     16045                                  NaN     -3667
# 323458    565304     16259                                  NaN     -3167
# 160145   C550456     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR     -3114
# 263884    560039     20713         wrongly marked. 23343 in box     -3100
# ...

# %%
#nombre de descriptions différentes
np.count_nonzero(data['Description'].unique())
# Out:
# 4224

# %%
#nombre de stockcode différents
np.count_nonzero(data['StockCode'].unique())
# Out:
# 4070

# %%
#nombre de InvoiceNo différents
np.count_nonzero(data['InvoiceNo'].unique())
# Out:
# 25900

# %%
#création d'une table avec les entrées pour lesquelles CustomerID = Nan
clients_nan = data[data[['CustomerID']].isna().any(axis=1)]
clients_nan.head(10)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 622     536414     22139                                  NaN        56
# 1443    536544     21773      DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774      DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786                   POLKADOT RAIN HAT          4
# 1446    536544     21787                RAIN PONCHO RETROSPOT         2
# 1447    536544     21790                   VINTAGE SNAP CARDS         9
# 1448    536544     21791   VINTAGE HEADS AND TAILS CARD GAME          2
# 1449    536544     21801  CHRISTMAS TREE DECORATION WITH BELL        10
# 1450    536544     21802      CHRISTMAS TREE HEART DECORATION         9
# 1451    536544     21803       CHRISTMAS TREE STAR DECORATION        11
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 622   12/01/2010 11:52       0.00         NaN  United Kingdom
# ...

# %%
#suppression des lignes pour lesquelles description=Nan (car ce cas a été étudié plus haut)
clients_nan=clients_nan.dropna(axis=0,how='all', subset=['Description'])

# %%
#affichage de la table lorsque quantité négative
clients_nan[clients_nan['Quantity']<0]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 7313      537032     21275                                  ?       -30
# 11502    C537251     22429         ENAMEL MEASURING JUG CREAM        -2
# 11503    C537251     22620        4 TRADITIONAL SPINNING TOPS        -8
# 11504    C537251     21890  S/6 WOODEN SKITTLES IN COTTON BAG        -2
# 11505    C537251     22564             ALPHABET STENCIL CRAFT        -5
# ...          ...       ...                                ...       ...
# 535333    581210     23395                              check       -26
# 535335    581212     22578                               lost     -1050
# 535336    581213     22576                              check       -30
# 536908    581226     23090                            missing      -338
# 538919    581422     23169                            smashed      -235
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# calcul du nombre de fois où l'on a des quantités négatives 
clients_nan[clients_nan['Quantity']<0].Quantity.count()
#857 valeurs négatives pour la quantité dans notre jeu de données
# Out:
# 857

# %%
# calcul du nombre de fois où l'on a des quantités positives 
clients_nan[clients_nan['Quantity']>0].Quantity.count()
#132769
# Out:
# 132769

# %%
#as-t-on des quantités = 0 ?
clients_nan[clients_nan['Quantity']==0].Quantity.count()
#--> non
# Out:
# 0

# %%
#affichage de la table lorsque quantité négative, ordonné par rapport à InoviceNo (pour détecter présence de 'C')
clients_nan[clients_nan['Quantity']<0].sort_values(by='InvoiceNo', ascending=True)
#là, nous avons des numéros de factures avec le caractère 'C'
# Out:
#        InvoiceNo  StockCode                         Description  Quantity  \
# 7313      537032      21275                                   ?       -30
# 13217     537425     84968F                               check       -20
# 13218     537426     84968E                               check       -35
# 13264     537432     35833G                             damages       -43
# 21338     538072      22423                              faulty       -13
# ...          ...        ...                                 ...       ...
# 492207   C578097      22112          CHOCOLATE HOT WATER BOTTLE       -48
# 514984   C579757      47469  ASSORTED SHAPES PHOTO CLIP SILVER        -24
# 516454   C579907      22169    FAMILY ALBUM WHITE PICTURE FRAME        -2
# 524601   C580604  AMAZONFEE                          AMAZON FEE        -1
# 524602   C580605  AMAZONFEE                          AMAZON FEE        -1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
clients_nan[clients_nan['Quantity']<0].sort_values(by='InvoiceNo', ascending=True).head(40)
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 7313      537032     21275                              ?       -30
# 13217     537425    84968F                          check       -20
# 13218     537426    84968E                          check       -35
# 13264     537432    35833G                        damages       -43
# 21338     538072     22423                         faulty       -13
# 21518     538090     20956                              ?      -723
# 22296     538161    46000S                   Dotcom sales      -100
# 22297     538162    46000M                   Dotcom sales      -100
# 42564     540010     22501     reverse 21/5/10 adjustment      -100
# 42566     540012     22502     reverse 21/5/10 adjustment      -100
# 43662     540100     22837                              ?      -106
# 50806     540558     21258                              ?       -29
# 50849     540564     22617           mouldy, thrown away.     -2600
# ...

# %%
####################################################

# %%
''' Test statistique et étude de corrélation'''

# %%
####################################################

# %%
# Tests statistiques pour évaluer la dépendance

#Test de l'anova pour relation entre 1 variable quantitative et 1 qualitative 
#relation entre les variables country et quantity
import statsmodels.api 
result = statsmodels.formula.api.ols('Quantity ~ Country', data = data).fit()
table = statsmodels.api.stats.anova_lm(result)

table
# p-value < 5%, on rejette l'hypothèse d'indépendance entre quantity et country
# Out:
#                 df        sum_sq        mean_sq          F        PR(>F)
# Country       37.0  2.224778e+07  601291.218674  12.653014  5.004992e-76
# Residual  541871.0  2.575057e+10   47521.581529        NaN           NaN

# %%
#relation entre les variables country et unitprice
import statsmodels.api 
result = statsmodels.formula.api.ols('UnitPrice ~ Country', data = data).fit()
table = statsmodels.api.stats.anova_lm(result)

table
#p-value < 5%, on rejette l'hypothèse d'indépendance entre country et unitprice
# Out:
#                 df        sum_sq       mean_sq         F        PR(>F)
# Country       37.0  3.014791e+06  81480.838492  8.707502  3.581764e-47
# Residual  541871.0  5.070582e+09   9357.544783       NaN           NaN

# %%
# Test du Chi2 pour relation entre 2 va qualitatives
#création d'un tableau de contingence entre variable country et description
table = pd.crosstab(data["Country"],data["Description"])
table
# Out:
# Description            4 PURPLE FLOCK DINNER CANDLES  \
# Country
# Australia                                          0
# Austria                                            0
# Bahrain                                            0
# Belgium                                            0
# Brazil                                             0
# Canada                                             0
# Channel Islands                                    0
# Cyprus                                             0
# Czech Republic                                     0
# Denmark                                            0
# EIRE                                               1
# European Community                                 0
# Finland                                            0
# France                                             0
# Germany                                            0
# Greece                                             0
# ...

# %%
#test du chi2 entre country et description
from scipy.stats import chi2_contingency

resultats_test = chi2_contingency(table)
statistique = resultats_test[0]
p_valeur = resultats_test[1]
degre_liberte = resultats_test[2]

print(statistique,p_valeur,degre_liberte)
#p-value = 0 <5%, on rejette l'hypothèse d'independance
# Out:
# 248913.32358964396 0.0 156214

# %%
#calcul du V de cramer
def V_Cramer (table,N):
    stat_chi2 = chi2_contingency(table)[0]
    k = table.shape[0]
    r = table.shape[1]
    phi = max(0,(stat_chi2/N)-((k-1)*(r-1)/(N-1)))
    k_corr = k - (np.square(k-1)/(N-1))
    r_corr = r - (np.square(r-1)/(N-1))
    return np.sqrt(phi/min(k_corr - 1,r_corr - 1))

V_Cramer(table,data.shape[0])
# Out:
# 0.06799678673538075

# %%
#j'enlève les données manquantes pour effectuer des tests stats avec la variable CustomerID
data_sans_na=data.dropna(axis=0, how='all', subset=['CustomerID'])

#conversion de customerID en int
data_sans_na['CustomerID'] = data_sans_na['CustomerID'].astype('int')
data_sans_na.head(10)
# Out:
# <ipython-input-4-66f60aed494d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sans_na['CustomerID'] = data_sans_na['CustomerID'].astype('int')
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# ...

# %%
#test du chi2 entre customeriD et description
table2 = pd.crosstab(data_sans_na["CustomerID"],data_sans_na["Description"])

resultats_test = chi2_contingency(table2)
statistique = resultats_test[0]
p_valeur = resultats_test[1]
degre_liberte = resultats_test[2]

print(statistique,p_valeur,degre_liberte)
#p-value = 0 <<< 5%, on rejette l'hypothèse d'indépendance
# Out:
# 23152722.04815031 0.0 17025045

# %%
#test du chi2 entre customeriD et country
table3 = pd.crosstab(data_sans_na["CustomerID"],data_sans_na["Country"])


resultats_test = chi2_contingency(table3)
statistique = resultats_test[0]
p_valeur = resultats_test[1]
degre_liberte = resultats_test[2]

print(statistique,p_valeur,degre_liberte)
#p-value = 0 <<< 5%, on rejette l'hypothèse d'indépendance
# Out:
# 14538442.95014086 0.0 157356

# %%
#test du chi2 entre customeriD et InvoiceNo
table4 = pd.crosstab(data_sans_na["CustomerID"],data_sans_na["InvoiceNo"])

resultats_test = chi2_contingency(table4)
statistique = resultats_test[0]
p_valeur = resultats_test[1]
degre_liberte = resultats_test[2]

print(statistique,p_valeur,degre_liberte)
#p-value = 0 <<< 5%, on rejette l'hypothèse d'indépendance
# Out:
# 1778249559.0000043 0.0 96988119

# %%
#test du chi2 entre customeriD et StockCode
table5 = pd.crosstab(data_sans_na["CustomerID"],data_sans_na["StockCode"])

resultats_test = chi2_contingency(table5)
statistique = resultats_test[0]
p_valeur = resultats_test[1]
degre_liberte = resultats_test[2]

print(statistique,p_valeur,degre_liberte)
#p-value = 0 <<< 5%, on rejette l'hypothèse d'indépendance
# Out:
# 22019798.207198337 0.0 16098393

# %%
#test du chi2 entre customeriD et InvoiceDate
table6 = pd.crosstab(data_sans_na["CustomerID"],data_sans_na["InvoiceDate"])

resultats_test = chi2_contingency(table6)
statistique = resultats_test[0]
p_valeur = resultats_test[1]
degre_liberte = resultats_test[2]

print(statistique,p_valeur,degre_liberte)
#p-value = 0 <<< 5%, on rejette l'hypothèse d'indépendance
# Out:
# 1664150917.6826541 0.0 89426289

# %%
#relation entre customerID et unitprice

result = statsmodels.formula.api.ols('UnitPrice ~ CustomerID', data = data_sans_na).fit()
table = statsmodels.api.stats.anova_lm(result)

table
#p-value < 5%, on rejette l'hypothèse d'indépendance entre customerID et unitprice
# Out:
#                   df        sum_sq       mean_sq         F    PR(>F)
# CustomerID       1.0  4.063646e+04  40636.458298  8.457993  0.003635
# Residual    406827.0  1.954602e+09   4804.503568       NaN       NaN

# %%
#relation entre customerID et quantity

result = statsmodels.formula.api.ols('Quantity ~ CustomerID', data = data_sans_na).fit()
table = statsmodels.api.stats.anova_lm(result)

table
#p-value > 5%, on ne rejette pas l'hypothèse d'indépendance entre customerID et quantity
# Out:
#                   df        sum_sq        mean_sq         F    PR(>F)
# CustomerID       1.0  3.260400e+05  326040.014929  5.271656  0.021676
# Residual    406827.0  2.516133e+10   61847.742896       NaN       NaN

# %%
#matrice de corrélation
data.corr()
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
#relation entre les variables quantity et InvoiceNo
import statsmodels.api 
result = statsmodels.formula.api.ols('Quantity ~ InvoiceNo', data = data).fit()
table = statsmodels.api.stats.anova_lm(result)

table
#p-value < 5%, on rejette l'hypothèse d'indépendance entre country et unitprice
